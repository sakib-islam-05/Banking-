# %%
import os
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder,LabelEncoder
from sklearn.metrics import classification_report,confusion_matrix
from imblearn.over_sampling import SMOTE

# %%
df=pd.read_csv('../data/processed_data.csv',usecols=lambda column:not column.startswith('Unnamed'))
df.head()
# Out:
#    CreditScore Geography        Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          614     Spain        Female   40       3  113348.50              1
# 1          758    France        Female   34       1  154139.45              1
# 2          541   Germany        Female   39       9  100116.67              1
# 3          481    France  NotSpecified   37       8  152303.66              2
# 4          711    France        Female   37       8  113899.92              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1         77789.01       0
# 1          1               1         60728.89       0
# 2          1               1        199808.10       1
# 3          1               1        175082.20       0
# 4          0               0         80215.20       0

# %% [markdown]
# ## Models Training
# ### Let's start by splitting our dataframe into separate objects:
# #### y for the target varibale
# #### X for the input features

# %%
x=df.drop('Exited',axis=1)
y=df['Exited']

# %%
print(x.shape,y.shape)
# Out:
# (10000, 10) (10000,)

# %%
num_col=x.select_dtypes(include='number').columns.to_list()
num_col
# Out:
# ['CreditScore',
#  'Age',
#  'Tenure',
#  'Balance',
#  'NumOfProducts',
#  'HasCrCard',
#  'IsActiveMember',
#  'EstimatedSalary']

# %%
cal_col=x.select_dtypes(include='object').columns.to_list()
cal_col
# Out:
# ['Geography', 'Gender']

# %%
for column in num_col:
    x[column]=MinMaxScaler().fit_transform(x[[column]])

# %%
for column in cal_col:
    x[column]=x[[column]].apply(LabelEncoder().fit_transform)

# %%
def class_count(a):
    counter=Counter(a)
    kv=[list(counter.keys()),list(counter.values())]
    abt2 = pd.DataFrame(np.array(kv).T, columns=['Exited','Count'])
    abt2['Count'] = abt2['Count'].astype('int64')
    abt2['%'] = round(abt2['Count'] / a.shape[0] * 100, 2)
    return abt2.sort_values('Count',ascending=False)

# %%
class_count(y)
# Out:
#    Exited  Count      %
# 0       0   7963  79.63
# 1       1   2037  20.37

# %% [markdown]
# ## Create a Train Test Split
# #### We will continue with splitting our data into separate training and test sets.
# #### 30% of observations will be set aside for the test set
# #### the rest, 70%, will be used as the training set

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)

# %%
print(len(x_train),len(x_test),len(y_train),len(y_test))
# Out:
# 7000 3000 7000 3000

# %%
x_smote,y_smote=SMOTE().fit_resample(x_train,y_train)

# %%
print(len(x_smote),len(y_smote))
# Out:
# 11218 11218

# %% [markdown]
# ### Fit Model

# %%
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV
dt_param_grid = {
            'max_leaf_nodes': [2, 10, 20, 30], 
            'min_samples_split': [2, 3, 4],
            'criterion': ['gini', 'entropy']
            }

dt_grid = GridSearchCV(DT, dt_param_grid, verbose=3, cv= 5, scoring='accuracy')

# %%
dt_grid.fit(x_smote,y_smote)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END criterion=gini, max_leaf_nodes=2, min_samples_split=2;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=gini, max_leaf_nodes=2, min_samples_split=2;, score=0.696 total time=   0.0s
# [CV 3/5] END criterion=gini, max_leaf_nodes=2, min_samples_split=2;, score=0.713 total time=   0.0s
# [CV 4/5] END criterion=gini, max_leaf_nodes=2, min_samples_split=2;, score=0.699 total time=   0.0s
# [CV 5/5] END criterion=gini, max_leaf_nodes=2, min_samples_split=2;, score=0.696 total time=   0.0s
# [CV 1/5] END criterion=gini, max_leaf_nodes=2, min_samples_split=3;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=gini, max_leaf_nodes=2, min_samples_split=3;, score=0.696 total time=   0.0s
# [CV 3/5] END criterion=gini, max_leaf_nodes=2, min_samples_split
5] END criterion=gini, max_leaf_nodes=30, min_samples_split=4;, score=0.869 total time=   0.0s
# [CV 5/5] END criterion=gini, max_leaf_nodes=30, min_samples_split=4;, score=0.842 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=2;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=2;, score=0.696 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=2;, score=0.718 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=2;, score=0.699 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=2;, score=0.700 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=3;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=3;, score=0.696 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=3;, score=0.718 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=3;, score=0.699 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=3;, score=0.700 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=4;, score=0.686 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=4;, score=0.696 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=4;, score=0.718 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=4;, score=0.699 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=2, min_samples_split=4;, score=0.700 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=2;, score=0.735 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=2;, score=0.795 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=2;, score=0.795 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=2;, score=0.794 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=2;, score=0.792 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=3;, score=0.735 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=3;, score=0.795 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=3;, score=0.795 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=3;, score=0.794 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=3;, score=0.792 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=4;, score=0.735 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=4;, score=0.795 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=4;, score=0.795 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=4;, score=0.794 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=10, min_samples_split=4;, score=0.792 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=2;, score=0.735 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=2;, score=0.818 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=2;, score=0.827 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=2;, score=0.822 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=2;, score=0.809 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=3;, score=0.735 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=3;, score=0.818 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=3;, score=0.827 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=3;, score=0.822 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=3;, score=0.809 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=4;, score=0.735 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=4;, score=0.818 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=4;, score=0.827 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=4;, score=0.822 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=20, min_samples_split=4;, score=0.809 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=2;, score=0.741 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=2;, score=0.828 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=2;, score=0.850 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=2;, score=0.866 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=2;, score=0.842 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=3;, score=0.741 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=3;, score=0.828 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=3;, score=0.850 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=3;, score=0.866 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=3;, score=0.842 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=4;, score=0.741 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=4;, score=0.828 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=4;, score=0.850 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=4;, score=0.866 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_leaf_nodes=30, min_samples_split=4;, score=0.842 total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_leaf_nodes': [2, 10, 20, 30],
#                          'min_samples_split': [2, 3, 4]},
#              scoring='accuracy', verbose=3)

# %%
print(dt_grid.best_params_)
# Out:
# {'criterion': 'gini', 'max_leaf_nodes': 30, 'min_samples_split': 2}

# %%
print(dt_grid.best_score_)
# Out:
# 0.8308120411055031

# %%
print(f'Training Data Score : {dt_grid.score(x_train,y_train)}')
print(f'Training Data Score : {dt_grid.score(x_test,y_test)}')
# Out:
# Training Data Score : 0.8314285714285714
# Training Data Score : 0.829

# %%
prediction=dt_grid.predict(x_test)

# %%
pd.DataFrame({'Prediction':prediction,'Actual':y_test})
# Out:
#       Prediction  Actual
# 937            1       1
# 9355           0       0
# 2293           0       0
# 192            0       0
# 8675           0       0
# ...          ...     ...
# 4964           0       0
# 8978           0       0
# 7540           0       0
# 5275           0       1
# 9654           1       1
#
# [3000 rows x 2 columns]

# %%
print(classification_report(prediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      2349
#            1       0.61      0.60      0.60       651
#
#     accuracy                           0.83      3000
#    macro avg       0.75      0.75      0.75      3000
# weighted avg       0.83      0.83      0.83      3000

# %%
import joblib
filename = '../Models/decision_tree.sav'
joblib.dump(dt_grid, filename)
# Out:
# ['../Models/decision_tree.sav']

# %%
dt_model=joblib.load(filename)
print(dt_model.score(x_test,y_test))
# Out:
# 0.829
